# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import math
from rdkit.Chem import AllChem
import rdkit
Chem = rdkit.Chem
from rdkit.Chem import GraphDescriptors
from rdkit.Chem import MACCSkeys, rdFingerprintGenerator

# %%
baseall = pd.read_csv('./data/base_all.tsv', sep = '\t')

# %%
baseall.head()
# Out:
#   Molecule ChEMBL ID       Molecule Name  Molecule Max Phase  \
# 0       CHEMBL247416                 NaN                 NaN
# 1       CHEMBL429477                 NaN                 NaN
# 2       CHEMBL393850                 NaN                 NaN
# 3         CHEMBL1546  HYDROXYAMPHETAMINE                 4.0
# 4       CHEMBL502753                 NaN                 NaN
#
#    Molecular Weight  #RO5 Violations  AlogP       Compound Key  \
# 0            541.64              1.0   3.56  18, diastereomers
# 1            575.78              1.0   2.68                 27
# 2            445.59              0.0   1.85  16, diastereomers
# 3            151.21              0.0   1.28                  2
# 4            751.97              2.0   5.02                 10
#
#                                               Smiles Standard Type  \
# 0  CC1CC1CNc1cc(C(=O)N[C@@H](Cc2ccccc2)[C@@H](N)C...          IC50
# 1  COCCN(C[C@H]1C[C@@H]1C)c1cc(C(=O)N[C@@H](Cc2cc...          IC50
# 2  CC1CC1CNc1cc(C(=O)N[C@H](CN)Cc2ccccc2)cc(N(C)S...          IC50
# 3                                  CC(N)Cc1ccc(O)cc1          IC50
# 4  CC(C)C[C@H](NC(=O)c1cc(C(=O)N[C@H](C)c2ccc(F)c...          IC50
#
#   Standard Relation  ...     Target Type Document ChEMBL ID  Source ID  \
# 0               '='  ...  SINGLE PROTEIN      CHEMBL1139116          1
# 1               '='  ...  SINGLE PROTEIN      CHEMBL1139116          1
# 2               '='  ...  SINGLE PROTEIN      CHEMBL1139116          1
# 3               '>'  ...  SINGLE PROTEIN      CHEMBL1142369          1
# 4               '<'  ...  SINGLE PROTEIN      CHEMBL1152701          1
#
#       Source Description      Document Journal Document Year  Cell ChEMBL ID  \
# 0  Scientific Literature  Bioorg Med Chem Lett          2007             NaN
# 1  Scientific Literature  Bioorg Med Chem Lett          2007             NaN
# 2  Scientific Literature  Bioorg Med Chem Lett          2007             NaN
# 3  Scientific Literature  Bioorg Med Chem Lett          2008             NaN
# 4  Scientific Literature       Bioorg Med Chem          2009   CHEMBL3307715
#
#    Properties  Action Type  Standard Text Value
# 0         NaN          NaN                  NaN
# 1         NaN          NaN                  NaN
# 2         NaN          NaN                  NaN
# 3         NaN          NaN                  NaN
# 4         NaN          NaN                  NaN
#
# [5 rows x 47 columns]

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# check missing values
baseall.isna().sum()
# Out:
# Molecule ChEMBL ID                0
# Molecule Name                 10427
# Molecule Max Phase            10547
# Molecular Weight                  0
# #RO5 Violations                  65
# AlogP                            65
# Compound Key                      0
# Smiles                            0
# Standard Type                     0
# Standard Relation               147
# Standard Value                  147
# Standard Units                  147
# pChEMBL Value                   903
# Data Validity Comment         10364
# Comment                        6400
# Uo Units                        147
# Ligand Efficiency BEI           931
# Ligand Efficiency LE            972
# Ligand Efficiency LLE           972
# Ligand Efficiency SEI           972
# Potential Duplicate               0
# Assay ChEMBL ID                   0
# Assay Description                 0
# Assay Type                        0
# BAO Format ID                     0
# BAO Label                         0
# Assay Organism                 2519
# Assay Tissue ChEMBL ID        10619
# Assay Tissue Name             10619
# Assay Cell Type                8205
# Assay Subcellular Fraction    10619
# Assay Parameters              10619
# Assay Variant Accession       10619
# Assay Variant Mutation        10619
# Target ChEMBL ID                  0
# Target Name                       0
# Target Organism                   0
# Target Type                       0
# Document ChEMBL ID                0
# Source ID                         0
# Source Description                0
# Document Journal               4072
# Document Year                     0
# Cell ChEMBL ID                 8523
# Properties                    10382
# Action Type                   10226
# Standard Text Value           10619
# dtype: int64

# %% [markdown]
# #### 1. Check for duplicates of IDs

# %%
baseall.shape
# Out:
# (10619, 47)

# %%
baseall = baseall.drop_duplicates(subset=['Molecule ChEMBL ID'])

# %%
baseall.shape
# Out:
# (7464, 47)

# %%
# Target organism
baseall["Target Organism"].unique()
# Out:
# array(['Homo sapiens'], dtype=object)

# %% [markdown]
# #### 2. Select columns necessory for further analysis

# %%
baseall = baseall[['Molecule ChEMBL ID', 'Molecular Weight', 'Standard Value', 'Standard Units', '#RO5 Violations', 'AlogP',  'Smiles']]
baseall
# Out:
#       Molecule ChEMBL ID  Molecular Weight  Standard Value Standard Units  \
# 0           CHEMBL247416            541.64             2.0             nM
# 1           CHEMBL429477            575.78            66.0             nM
# 2           CHEMBL393850            445.59           279.0             nM
# 3             CHEMBL1546            151.21        100000.0             nM
# 4           CHEMBL502753            751.97          1000.0             nM
# ...                  ...               ...             ...            ...
# 10614      CHEMBL5220695            377.49            15.1             nM
# 10615      CHEMBL5187186            329.81            96.0             nM
# 10616      CHEMBL5184716            371.39           851.0             nM
# 10617      CHEMBL5186773            389.38            12.0             nM
# 10618      CHEMBL5184228            509.43             5.9             nM
#
#        #RO5 Violations  AlogP  \
# 0                  1.0   3.56
# 1                  1.0   2.68
# 2                  0.0   1.85
# 3                  0.0   1.28
# 4                  2.0   5.02
# ...                ...    ...
# 10614              0.0   3.35
# 10615              0.0   4.15
# 10616              0.0   3.14
# 10617              0.0   3.43
# 10618              1.0   4.27
#
#                                                   Smiles
# 0      CC1CC1CNc1cc(C(=O)N[C@@H](Cc2ccccc2)[C@@H](N)C...
# 1      COCCN(C[C@H]1C[C@@H]1C)c1cc(C(=O)N[C@@H](Cc2cc...
# 2      CC1CC1CNc1cc(C(=O)N[C@H](CN)Cc2ccccc2)cc(N(C)S...
# 3                                      CC(N)Cc1ccc(O)cc1
# 4      CC(C)C[C@H](NC(=O)c1cc(C(=O)N[C@H](C)c2ccc(F)c...
# ...                                                  ...
# 10614      CC(C)(C)OC(=O)Nc1ccc(O)c(C(=O)NCCCN2CCCCC2)c1
# 10615  C[C@@]1(c2cc(-c3ccc(Cl)cn3)ccc2F)C[C@@H]2C[C@@...
# 10616  COc1cnc(-c2ccc(F)c([C@]3(CF)CC[C@](C)(C#N)C(N)...
# 10617  COc1cnc(-c2ccc(F)c([C@]3(C(F)F)CC[C@@](C)(C#N)...
# 10618  C[C@@]1(c2cc(-c3cc4c(cn3)OC(F)(F)O4)ccc2F)CC[C...
#
# [7464 rows x 7 columns]

# %%
baseall = baseall.rename(columns={'Molecule ChEMBL ID': 'ChEMBL ID', 'Standard Value': 'IC50'})

# %%
#Change column name 'standard Value'  to 'IC50' and 'Molecule ChEMBL ID' to 'ChEMBL ID'
baseall = baseall.rename(columns={'Molecule ChEMBL ID': 'ChEMBL ID', 'Standard Value': 'IC50'})

# %%
baseall
# Out:
#            ChEMBL ID  Molecular Weight      IC50 Standard Units  \
# 0       CHEMBL247416            541.64       2.0             nM
# 1       CHEMBL429477            575.78      66.0             nM
# 2       CHEMBL393850            445.59     279.0             nM
# 3         CHEMBL1546            151.21  100000.0             nM
# 4       CHEMBL502753            751.97    1000.0             nM
# ...              ...               ...       ...            ...
# 10614  CHEMBL5220695            377.49      15.1             nM
# 10615  CHEMBL5187186            329.81      96.0             nM
# 10616  CHEMBL5184716            371.39     851.0             nM
# 10617  CHEMBL5186773            389.38      12.0             nM
# 10618  CHEMBL5184228            509.43       5.9             nM
#
#        #RO5 Violations  AlogP  \
# 0                  1.0   3.56
# 1                  1.0   2.68
# 2                  0.0   1.85
# 3                  0.0   1.28
# 4                  2.0   5.02
# ...                ...    ...
# 10614              0.0   3.35
# 10615              0.0   4.15
# 10616              0.0   3.14
# 10617              0.0   3.43
# 10618              1.0   4.27
#
#                                                   Smiles
# 0      CC1CC1CNc1cc(C(=O)N[C@@H](Cc2ccccc2)[C@@H](N)C...
# 1      COCCN(C[C@H]1C[C@@H]1C)c1cc(C(=O)N[C@@H](Cc2cc...
# 2      CC1CC1CNc1cc(C(=O)N[C@H](CN)Cc2ccccc2)cc(N(C)S...
# 3                                      CC(N)Cc1ccc(O)cc1
# 4      CC(C)C[C@H](NC(=O)c1cc(C(=O)N[C@H](C)c2ccc(F)c...
# ...                                                  ...
# 10614      CC(C)(C)OC(=O)Nc1ccc(O)c(C(=O)NCCCN2CCCCC2)c1
# 10615  C[C@@]1(c2cc(-c3ccc(Cl)cn3)ccc2F)C[C@@H]2C[C@@...
# 10616  COc1cnc(-c2ccc(F)c([C@]3(CF)CC[C@](C)(C#N)C(N)...
# 10617  COc1cnc(-c2ccc(F)c([C@]3(C(F)F)CC[C@@](C)(C#N)...
# 10618  C[C@@]1(c2cc(-c3cc4c(cn3)OC(F)(F)O4)ccc2F)CC[C...
#
# [7339 rows x 7 columns]

# %%
# drop rows with missing values
baseall = baseall.dropna(axis=1, how='all')

# %%
baseall.head()
# Out:
#       ChEMBL ID  Molecular Weight      IC50 Standard Units  #RO5 Violations  \
# 0  CHEMBL247416            541.64       2.0             nM              1.0
# 1  CHEMBL429477            575.78      66.0             nM              1.0
# 2  CHEMBL393850            445.59     279.0             nM              0.0
# 3    CHEMBL1546            151.21  100000.0             nM              0.0
# 4  CHEMBL502753            751.97    1000.0             nM              2.0
#
#    AlogP                                             Smiles  pIC50
# 0   3.56  CC1CC1CNc1cc(C(=O)N[C@@H](Cc2ccccc2)[C@@H](N)C...   8.70
# 1   2.68  COCCN(C[C@H]1C[C@@H]1C)c1cc(C(=O)N[C@@H](Cc2cc...   7.18
# 2   1.85  CC1CC1CNc1cc(C(=O)N[C@H](CN)Cc2ccccc2)cc(N(C)S...   6.55
# 3   1.28                                  CC(N)Cc1ccc(O)cc1   4.00
# 4   5.02  CC(C)C[C@H](NC(=O)c1cc(C(=O)N[C@H](C)c2ccc(F)c...   6.00

# %%
def convert_ic50_to_pic50(IC50_value):
    pIC50_value = 9 - math.log10(IC50_value)
    return pIC50_value

# %%
baseall["pIC50"] = baseall.apply(lambda x: round(convert_ic50_to_pic50(x.IC50), 2), axis=1)

# %%
baseall.head()
# Out:
#       ChEMBL ID  Molecular Weight      IC50 Standard Units  #RO5 Violations  \
# 0  CHEMBL247416            541.64       2.0             nM              1.0
# 1  CHEMBL429477            575.78      66.0             nM              1.0
# 2  CHEMBL393850            445.59     279.0             nM              0.0
# 3    CHEMBL1546            151.21  100000.0             nM              0.0
# 4  CHEMBL502753            751.97    1000.0             nM              2.0
#
#    AlogP                                             Smiles  pIC50
# 0   3.56  CC1CC1CNc1cc(C(=O)N[C@@H](Cc2ccccc2)[C@@H](N)C...   8.70
# 1   2.68  COCCN(C[C@H]1C[C@@H]1C)c1cc(C(=O)N[C@@H](Cc2cc...   7.18
# 2   1.85  CC1CC1CNc1cc(C(=O)N[C@H](CN)Cc2ccccc2)cc(N(C)S...   6.55
# 3   1.28                                  CC(N)Cc1ccc(O)cc1   4.00
# 4   5.02  CC(C)C[C@H](NC(=O)c1cc(C(=O)N[C@H](C)c2ccc(F)c...   6.00

# %%
baseall.dtypes
# Out:
# ChEMBL ID            object
# Molecular Weight    float64
# IC50                float64
# Standard Units       object
# #RO5 Violations     float64
# AlogP               float64
# Smiles               object
# pIC50               float64
# dtype: object

# %%
baseall['pIC50'].max(), baseall['pIC50'].min()
# Out:
# (12.7, 1.07)

# %%
fig, (axes) = plt.subplots(2,2, figsize = (12,8))

axes[0,0].hist(baseall['Molecular Weight'], color = 'navy', bins = 100)
axes[0,0].set_xlabel('Molecular Weight, Da')
axes[0,0].set_ylabel('Frequency')
axes[0,1].hist(baseall['AlogP'], color = 'orange', bins = 100)
axes[0,1].set_xlabel('LogP')
# axes[0,2].hist(emb_bios['HBA'], color = 'skyblue', bins = 15)
# axes[0,2].set_xlabel('No. hydrogen bond acceptors')
# axes[1,0].hist(emb_bios['HBD'], color = 'rosybrown', bins = 15)
# axes[1,0].set_ylabel('Frequency')
# axes[1,0].set_xlabel('No. of hydrogen bond donors')
axes[1,0].hist(baseall['#RO5 Violations'], color = 'gold', bins = 20)
axes[1,0].set_xlabel('No. of RO5 violations')
axes[1,1].hist(baseall['pIC50'], color = 'teal', bins = 55)
axes[1,1].set_xlabel('pIC50(inhibitory activity on BACE1), M');

# %%
baseall.to_csv('./data/base_inhibitors.csv', index = False)
